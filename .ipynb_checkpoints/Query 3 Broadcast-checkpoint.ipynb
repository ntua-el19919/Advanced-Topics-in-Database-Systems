# %%
# Broadcast Implemantasion for Joins
from sedona.spark import *
from pyspark.sql import SparkSession
from pyspark.sql.types import StructField, StructType, IntegerType, FloatType, StringType, TimestampType
from pyspark.sql.functions import col, broadcast, date_format,  to_timestamp, round, format_number, concat, lit, when, count, sum, regexp_replace, trim
from pyspark.sql import Row
import time
import csv

hint_results = []
join_strategy = "BROADCAST"
# Create spark Session
spark = SparkSession.builder \
    .appName("Broadcast Hint") \
    .getOrCreate()
spark.catalog.clearCache()

# Create sedona context
sedona = SedonaContext.create(spark)
# Read the file from s3
geojson_path = "s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson"
blocks_df = sedona.read.format("geojson") \
            .option("multiLine", "true").load(geojson_path) \
            .selectExpr("explode(features) as features") \
            .select("features.*")
# Formatting magic
flattened_df = blocks_df.select( \
                [col(f"properties.{col_name}").alias(col_name) for col_name in \
                blocks_df.schema["properties"].dataType.fieldNames()] + ["geometry"]) \
            .drop("properties") \
            .drop("type") \
            .filter(col("CITY") == "Los Angeles")

#Query 3 Initialisation with Dataframe
start_time = time.time()

# Crime dataframe with parquet for quicker esults
crime_df = spark.read.parquet("s3://groups-bucket-dblab-905418150721/group12/main_dataset_parquet")\
                .filter((col("LON") != 0) | (col("LAT") != 0))  \
                .withColumn("point",ST_Point("LON", "LAT")) \
                .select("point")

# Income dataframe with median income
income_df = spark.read.csv(
    "s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv",
    header=True,
    inferSchema=True
)

res_income = income_df.withColumn("Estimated_Median_Income",
    regexp_replace(trim(col("Estimated Median Income")), "[^0-9]", "").cast(IntegerType())
    ).drop("Community","Estimated Median Income")

# Filter population for total population anf houses
zip_comm_population = flattened_df.select("ZCTA10", "COMM", "POP_2010", "HOUSING10", "geometry") \
    .filter((col("ZCTA10") > 0) & (col("POP_2010") > 0) & (col("HOUSING10") > 0) & (trim(col("COMM")) != "")) \
    .groupBy("ZCTA10", "COMM") \
    .agg(
        sum("POP_2010").alias("Total_Population_Zip_COMM"),
        sum("HOUSING10").alias("Total_Housing"),
        ST_Union_Aggr("geometry").alias("geometry")
    )
    
# Join incoma and cansus using zip coded

joined_income_df = zip_comm_population.hint(join_strategy).join(
   res_income,      
    zip_comm_population["ZCTA10"] == res_income["Zip Code"],
    "inner"  
    ) \
    .drop("ZCTA10","Zip Code") \
    .withColumn("Total income",col("Total_Housing") * col("Estimated_Median_Income")) \
    .drop("Estimated_Median_Income") \
    .groupBy("COMM") \
    .agg(sum("Total_Population_Zip_COMM")
    .alias("Total_Population"),sum("Total income")
    .alias("Total Income"),ST_Union_Aggr("geometry")
    .alias("geometry")) 


results = joined_income_df.hint(join_strategy).join(
                crime_df,    
                ST_Within(crime_df.point, 
                joined_income_df.geometry), "inner") \
                .groupBy("COMM","Total_Population","Total Income") \
                .agg(count(col("*")).alias("Total crimes")) \
                .withColumn("crime_rate",format_number((col("Total crimes")/col("Total_Population")),4)) \
                .withColumn("estimated_median_income",concat(lit("$"),format_number(round(col("Total Income") / col("Total_Population")), 0))) \
                .drop("Total Income","Total_Population","Total crimes") \
                .withColumnRenamed("COMM", "Location") \
                .orderBy(col("crime_rate").desc())
end_time = time.time()
print(f"Execution Time : {end_time - start_time} seconds")
# Store Results
hint_results.append(Row(
        Join_Strategy = join_strategy,
        Execution_Time = end_time - start_time)
                   )

hint_df = spark.createDataFrame(hint_results)

hint_df.write.mode("append").json("s3://groups-bucket-dblab-905418150721/group12/Q3/hint_res.json")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Execution Time : 2.563585042953491 seconds

# %%
# Explain for Broadcast
results.explain(mode="formatted")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# == Physical Plan ==
# AdaptiveSparkPlan (30)
# +- Sort (29)
#    +- Exchange (28)
#       +- HashAggregate (27)
#          +- Exchange (26)
#             +- HashAggregate (25)
#                +- Project (24)
#                   +- BroadcastIndexJoin (23)
#                      :- SpatialIndex (19)
#                      :  +- Filter (18)
#                      :     +- ObjectHashAggregate (17)
#                      :        +- Exchange (16)
#                      :           +- ObjectHashAggregate (15)
#                      :              +- Project (14)
#                      :                 +- BroadcastHashJoin Inner BuildLeft (13)
#                      :                    :- BroadcastExchange (9)
#                      :                    :  +- ObjectHashAggregate (8)
#                      :                    :     +- Exchange (7)
#                      :                    :        +- ObjectHashAggregate (6)
#                      :                    :           +- Project (5)
#                      :                    :              +- Filter (4)
#                      :                    :                 +- Generate (3)
#                      :                    :                    +- Filter (2)
#                      :                    :                       +- Scan geojson  (1)
#                      :                    +- Project (12)
#                      :                       +- Filter (11)
#                      :                          +- Scan csv  (10)
#                      +- Project (22)
#                         +- Filter (21)
#                            +- Scan parquet  (20)
#
#
# (1) Scan geojson
# Output [1]: [features#871]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/2010_Census_Blocks.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG10:string,BG10FIP10:string,BG12:string,CB10:string,CEN_FIP13:string,CITY:string,CITYCOM:string,COMM:string,CT10:string,CT12:string,CTCB10:string,HD_2012:bigint,HD_NAME:string,HOUSING10:bigint,LA_FIP10:string,OBJECTID:bigint,POP_2010:bigint,PUMA10:string,SPA_2012:bigint,SPA_NAME:string,SUP_DIST:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,ZCTA10:string>,type:string>>>
#
# (2) Filter
# Input [1]: [features#871]
# Condition : ((size(features#871, true) > 0) AND isnotnull(features#871))
#
# (3) Generate
# Input [1]: [features#871]
# Arguments: explode(features#871), false, [features#879]
#
# (4) Filter
# Input [1]: [features#879]
# Condition : ((((isnotnull(features#879.properties.CITY) AND isnotnull(features#879.properties.ZCTA10)) AND isnotnull(features#879.properties.POP_2010)) AND isnotnull(features#879.properties.HOUSING10)) AND ((features#879.properties.CITY = Los Angeles) AND ((((cast(features#879.properties.ZCTA10 as int) > 0) AND (features#879.properties.POP_2010 > 0)) AND (features#879.properties.HOUSING10 > 0)) AND NOT (trim(features#879.properties.COMM, None) = ))))
#
# (5) Project
# Output [5]: [features#879.properties.ZCTA10 AS ZCTA10#912, features#879.properties.COMM AS COMM#895, features#879.properties.POP_2010 AS POP_2010#904L, features#879.properties.HOUSING10 AS HOUSING10#901L, features#879.geometry AS geometry#882]
# Input [1]: [features#879]
#
# (6) ObjectHashAggregate
# Input [5]: [ZCTA10#912, COMM#895, POP_2010#904L, HOUSING10#901L, geometry#882]
# Keys [2]: [ZCTA10#912, COMM#895]
# Functions [3]: [partial_sum(POP_2010#904L), partial_sum(HOUSING10#901L), partial_st_union_aggr(geometry#882, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@529c88f2, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)]
# Aggregate Attributes [3]: [sum#1289L, sum#1291L, buf#1293]
# Results [5]: [ZCTA10#912, COMM#895, sum#1290L, sum#1292L, buf#1294]
#
# (7) Exchange
# Input [5]: [ZCTA10#912, COMM#895, sum#1290L, sum#1292L, buf#1294]
# Arguments: hashpartitioning(ZCTA10#912, COMM#895, 1000), ENSURE_REQUIREMENTS, [plan_id=305]
#
# (8) ObjectHashAggregate
# Input [5]: [ZCTA10#912, COMM#895, sum#1290L, sum#1292L, buf#1294]
# Keys [2]: [ZCTA10#912, COMM#895]
# Functions [3]: [sum(POP_2010#904L), sum(HOUSING10#901L), st_union_aggr(geometry#882, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@529c88f2, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)]
# Aggregate Attributes [3]: [sum(POP_2010#904L)#1146L, sum(HOUSING10#901L)#1148L, ST_Union_Aggr(geometry#882)#1153]
# Results [5]: [ZCTA10#912, COMM#895, sum(POP_2010#904L)#1146L AS Total_Population_Zip_COMM#1147L, sum(HOUSING10#901L)#1148L AS Total_Housing#1149L, ST_Union_Aggr(geometry#882)#1153 AS geometry#1154]
#
# (9) BroadcastExchange
# Input [5]: [ZCTA10#912, COMM#895, Total_Population_Zip_COMM#1147L, Total_Housing#1149L, geometry#1154]
# Arguments: HashedRelationBroadcastMode(List(cast(cast(input[0, string, true] as int) as bigint)),false), [plan_id=308]
#
# (10) Scan csv
# Output [2]: [Zip Code#1122, Estimated Median Income#1124]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/LA_income_2015.csv]
# PushedFilters: [IsNotNull(Zip Code)]
# ReadSchema: struct<Zip Code:int,Estimated Median Income:string>
#
# (11) Filter
# Input [2]: [Zip Code#1122, Estimated Median Income#1124]
# Condition : isnotnull(Zip Code#1122)
#
# (12) Project
# Output [2]: [Zip Code#1122, cast(regexp_replace(trim(Estimated Median Income#1124, None), [^0-9], , 1) as int) AS Estimated_Median_Income#1128]
# Input [2]: [Zip Code#1122, Estimated Median Income#1124]
#
# (13) BroadcastHashJoin
# Left keys [1]: [cast(ZCTA10#912 as int)]
# Right keys [1]: [Zip Code#1122]
# Join type: Inner
# Join condition: None
#
# (14) Project
# Output [4]: [COMM#895, Total_Population_Zip_COMM#1147L, geometry#1154, (Total_Housing#1149L * cast(Estimated_Median_Income#1128 as bigint)) AS Total income#1191L]
# Input [7]: [ZCTA10#912, COMM#895, Total_Population_Zip_COMM#1147L, Total_Housing#1149L, geometry#1154, Zip Code#1122, Estimated_Median_Income#1128]
#
# (15) ObjectHashAggregate
# Input [4]: [COMM#895, Total_Population_Zip_COMM#1147L, geometry#1154, Total income#1191L]
# Keys [1]: [COMM#895]
# Functions [3]: [partial_sum(Total_Population_Zip_COMM#1147L), partial_sum(Total income#1191L), partial_st_union_aggr(geometry#1154, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@5d9eaa47, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)]
# Aggregate Attributes [3]: [sum#1283L, sum#1285L, buf#1287]
# Results [4]: [COMM#895, sum#1284L, sum#1286L, buf#1288]
#
# (16) Exchange
# Input [4]: [COMM#895, sum#1284L, sum#1286L, buf#1288]
# Arguments: hashpartitioning(COMM#895, 1000), ENSURE_REQUIREMENTS, [plan_id=313]
#
# (17) ObjectHashAggregate
# Input [4]: [COMM#895, sum#1284L, sum#1286L, buf#1288]
# Keys [1]: [COMM#895]
# Functions [3]: [sum(Total_Population_Zip_COMM#1147L), sum(Total income#1191L), st_union_aggr(geometry#1154, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@5d9eaa47, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)]
# Aggregate Attributes [3]: [sum(Total_Population_Zip_COMM#1147L)#1208L, sum(Total income#1191L)#1210L, ST_Union_Aggr(geometry#1154)#1215]
# Results [4]: [COMM#895, sum(Total_Population_Zip_COMM#1147L)#1208L AS Total_Population#1209L, sum(Total income#1191L)#1210L AS Total Income#1211L, ST_Union_Aggr(geometry#1154)#1215 AS geometry#1216]
#
# (18) Filter
# Input [4]: [COMM#895, Total_Population#1209L, Total Income#1211L, geometry#1216]
# Condition : isnotnull(geometry#1216)
#
# (19) SpatialIndex
# Arguments: geometry#1216: geometry, RTREE, false, false
#
# (20) Scan parquet
# Output [2]: [LAT#1042, LON#1043]
# Batched: true
# Location: InMemoryFileIndex [s3://groups-bucket-dblab-905418150721/group12/main_dataset_parquet]
# ReadSchema: struct<LAT:string,LON:string>
#
# (21) Filter
# Input [2]: [LAT#1042, LON#1043]
# Condition : ((NOT (cast(LON#1043 as int) = 0) OR NOT (cast(LAT#1042 as int) = 0)) AND isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  ))
#
# (22) Project
# Output [1]: [ **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS point#1073]
# Input [2]: [LAT#1042, LON#1043]
#
# (23) BroadcastIndexJoin
# Arguments: point#1073: geometry, LeftSide, RightSide, Inner, WITHIN
#
# (24) Project
# Output [3]: [COMM#895, Total_Population#1209L, Total Income#1211L]
# Input [5]: [COMM#895, Total_Population#1209L, Total Income#1211L, geometry#1216, point#1073]
#
# (25) HashAggregate
# Input [3]: [COMM#895, Total_Population#1209L, Total Income#1211L]
# Keys [3]: [COMM#895, Total_Population#1209L, Total Income#1211L]
# Functions [1]: [partial_count(1)]
# Aggregate Attributes [1]: [count#1281L]
# Results [4]: [COMM#895, Total_Population#1209L, Total Income#1211L, count#1282L]
#
# (26) Exchange
# Input [4]: [COMM#895, Total_Population#1209L, Total Income#1211L, count#1282L]
# Arguments: hashpartitioning(COMM#895, Total_Population#1209L, Total Income#1211L, 1000), ENSURE_REQUIREMENTS, [plan_id=321]
#
# (27) HashAggregate
# Input [4]: [COMM#895, Total_Population#1209L, Total Income#1211L, count#1282L]
# Keys [3]: [COMM#895, Total_Population#1209L, Total Income#1211L]
# Functions [1]: [count(1)]
# Aggregate Attributes [1]: [count(1)#1248L]
# Results [3]: [COMM#895 AS Location#1270, format_number((cast(count(1)#1248L as double) / cast(Total_Population#1209L as double)), 4) AS crime_rate#1254, concat($, format_number(round((cast(Total Income#1211L as double) / cast(Total_Population#1209L as double)), 0), 0)) AS estimated_median_income#1260]
#
# (28) Exchange
# Input [3]: [Location#1270, crime_rate#1254, estimated_median_income#1260]
# Arguments: rangepartitioning(crime_rate#1254 DESC NULLS LAST, 1000), ENSURE_REQUIREMENTS, [plan_id=324]
#
# (29) Sort
# Input [3]: [Location#1270, crime_rate#1254, estimated_median_income#1260]
# Arguments: [crime_rate#1254 DESC NULLS LAST], true, 0
#
# (30) AdaptiveSparkPlan
# Output [3]: [Location#1270, crime_rate#1254, estimated_median_income#1260]
# Arguments: isFinalPlan=false
